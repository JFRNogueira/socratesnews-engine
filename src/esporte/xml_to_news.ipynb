# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta, timezone
import re
class XmlToNews:

    def __init__(self, base_url):
        self.base_url = base_url
        self.xml_soup = self.get_xml()
        self.title =  self.get_title()
        self.news = self.get_news()
    
    def yesterday_url_str(self):
        ontem = datetime.now() - timedelta(days=1)
        data_formatada = f"{ontem.strftime('%d')}/{ontem.strftime('%m')}/{ontem.year}"
        return data_formatada
    
    def get_xml(self):
        browsers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome / 86.0.4240.198Safari / 537.36"}
        xml_content = requests.get(self.base_url, headers = browsers)
        soup = BeautifulSoup(xml_content.text, 'xml')
        return soup

    def get_title(self):
        title = self.xml_soup.find('title').get_text()
        return title.split(sep=' - ')[1]
    
    def get_source(self, url):
        if 'tntsports.com.br' in url:
            return 'tntsports'
        if 'correiobraziliense.com.br' in url:
            return 'correiobraziliense'
        if 'placar.com.br' in url:
            return 'placar'
        if 'flamengo.com.br' in url:
            return 'flamengo'
        if 'agoracomvoce.com.br' in url:
            return 'agoracomvoce'
        if 'folhape.com.br' in url:
            return 'folhape'
        if 'espn.com.br' in url:
            return 'espn'
        if 'uol.com.br' in url:
            return 'uol'
        if 'ge.globo.com' in url:
            return 'geglobo'
        return 'outro'

    def get_until_now(self, ts_str):
        date_time_obj = datetime.strptime(ts_str, '%Y-%m-%dT%H:%M:%SZ')
        date_time_obj = date_time_obj.replace(tzinfo=timezone.utc)
        current_time = datetime.now(timezone.utc)
        time_difference = current_time - date_time_obj
        hours_passed = time_difference.total_seconds() / 3600
        return hours_passed
        
                
    def get_news(self):
        news_all = self.xml_soup.find_all('entry')
        result = []
        for news in news_all:
            id = news.find('id').get_text()
            title = news.find('title', type='html').get_text()
            url = news.find('link').get('href')
            publishedAt = news.find('published').get_text()
            
            if(self.get_until_now(publishedAt) > 24):
                return result
            
            result += [{
                'id': id,
                'title': title,
                'url': url,
                'source': self.get_source(url),
                'publishedAt': publishedAt,
            }]
        return result

news = XmlToNews("https://www.google.com.br/alerts/feeds/11679571385690767210/11098906599508033294")
news.news
# Out:
# [{'id': 'tag:google.com,2013:googlealerts/feed:3571392005149868623',
#   'title': '<b>Flamengo</b> bate o Ceará na Gávea, pelo Brasileiro Sub-17',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://www.flamengo.com.br/noticias/futebol-de-base/flamengo-bate-o-ceara-na-gavea--pelo-brasileiro-sub-17&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw176ky0wPFr6aWvtBa_cG0a',
#   'source': 'flamengo',
#   'tilnow': 0.3185197302777778,
#   'publishedAt': '2024-08-15T18:46:12Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:2893688343268496447',
#   'title': 'Quem é Carlos Alcaraz, alvo do <b>Flamengo</b> e possível contratação mais cara do <b>futebol</b> brasileiro?',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://www.terra.com.br/esportes/flamengo/quem-e-carlos-alcaraz-alvo-do-flamengo-e-possivel-contratacao-mais-cara-do-futebol-brasileiro,faddb5d62c8230a399904e0f36c12dd31nqgp1u7.html&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw2uj20P4UjLjbkI1-iuuzYL',
#   'source': 'outro',
#   'tilnow': 0.39796417472222223,
#   'publishedAt': '2024-08-15T18:41:26Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:2605200593442149867',
#   'title': 'Escalação do <b>Flamengo</b>: Luiz Araújo entra no lugar de Cebolinha, lesionado, para enfrentar ...',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://www.lance.com.br/flamengo/escalacao-do-flamengo-luiz-araujo-entra-no-lugar-de-everton-cebolinha-que-esta-lesionado.html&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw2Fd2fiWLNn-b_nfIuXw3h0',
#   'source': 'outro',
#   'tilnow': 0.64935334,
#   'publishedAt': '2024-08-15T18:26:21Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:15279953499607399820',
#   'title': 'Ex-<b>Flamengo</b>, Natan deixa o Napoli e é anunciado pelo Betis, da Espanha - TNT Sports',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://tntsports.com.br/melhorfuteboldomundo/Ex-Flamengo-Natan-deixa-o-Napoli-e-e-anunciado-pelo-Betis-da-Espanha-20240815-0007.html&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw0YuxBNSvAM26LYQI-F-vRZ',
#   'source': 'tntsports',
#   'tilnow': 1.1276866733333333,
#   'publishedAt': '2024-08-15T17:57:39Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:1050709584123289625',
#   'title': '<b>Flamengo</b> na Libertadores: árbitro nunca apitou derrota do Bolívar e já cometeu falha bizarra',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://www.lance.com.br/flamengo/flamengo-na-libertadores-arbitro-nunca-apitou-derrota-do-bolivar-e-ja-cometeu-falha-bizarra.html&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw1_KEbcV-3RJgofP_r3_LXV',
#   'source': 'outro',
#   'tilnow': 1.2610200066666668,
#   'publishedAt': '2024-08-15T17:49:39Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:8647559723945489752',
#   'title': '<b>Flamengo</b> x Bolívar, com a Voz do Esporte, AO VIVO, às 20h - Correio Braziliense',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://www.correiobraziliense.com.br/esportes/2024/08/6920911-flamengo-x-bolivar-com-a-voz-do-esporte-ao-vivo-as-20h.html&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw1Jx2DWPjofpl6zY5Ft7E5V',
#   'source': 'correiobraziliense',
#   'tilnow': 1.5726866733333333,
#   'publishedAt': '2024-08-15T17:30:57Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:235285385297064572',
#   'title': 'Luis Fabiano fala sobre o <b>Flamengo</b> e afirma: “<b>Flamengo</b> não assusta” - Placar',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://placar.com.br/placar/luis-fabiano-fala-sobre-o-flamengo-e-afirma-flamengo-nao-assusta/&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw3N0_Xra1DY32AEkpkMjnSV',
#   'source': 'placar',
#   'tilnow': 1.8635200066666668,
#   'publishedAt': '2024-08-15T17:13:30Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:13259903072592725301',
#   'title': '<b>Flamengo</b> vence RedBull Bragantino fora de casa pelo Brasileiro Sub-20',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://www.flamengo.com.br/noticias/futebol-de-base/flamengo-vence-redbull-bragantino-fora-de-casa-pelo-brasileiro-sub-20&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw0BeiUIPrFseEjwvhqIb6Qd',
#   'source': 'flamengo',
#   'tilnow': 2.572686673333333,
#   'publishedAt': '2024-08-15T16:30:57Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:2445697453182550043',
#   'title': 'Copa Abdala movimenta o <b>futebol</b> de base neste segundo semestre - Portal Agora',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://www.agoracomvoce.com.br/2024/08/15/copa-abdala-movimenta-o-futebol-de-base-neste-segundo-semestre/&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw0B2riiWItemGXCJkTDi3cy',
#   'source': 'agoracomvoce',
#   'tilnow': 3.2271311177777777,
#   'publishedAt': '2024-08-15T15:51:41Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:9292393544896687663',
#   'title': '<b>Flamengo</b> x Bolívar e Nacional x São Paulo: veja horário e onde assistir aos jogos da Libertadores',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://www.folhape.com.br/esportes/flamengo-x-bolivar-e-nacional-x-sao-paulo-veja-horario-e-onde/354777/&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw2esyLyiz_scGSASUvRQ349',
#   'source': 'folhape',
#   'tilnow': 3.512686673333333,
#   'publishedAt': '2024-08-15T15:34:33Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:11280123902151320139',
#   'title': 'Rival do <b>Flamengo</b>, Bolívar chega para duelo da Libertadores sem artilheiro e após folga especial',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://www.espn.com.br/futebol/libertadores/artigo/_/id/14042675/libertadores-flamengo-bolivar-analise-chega-duelo-sem-artilheiro-folga-especial&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw0ykP-8LzHEETyX4Xr91L0a',
#   'source': 'espn',
#   'tilnow': 3.522964451111111,
#   'publishedAt': '2024-08-15T15:33:56Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:9681366763481456425',
#   'title': 'Jogo do <b>Flamengo</b> hoje: horário e onde assistir ao vivo - UOL',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://www.uol.com.br/esporte/futebol/ultimas-noticias/2024/08/15/jogo-do-flamengo-hoje-horario-e-onde-assistir-ao-vivo.htm&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw0qOHTz_lGN2MmVBvDicXon',
#   'source': 'uol',
#   'tilnow': 3.532964451111111,
#   'publishedAt': '2024-08-15T15:33:20Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:5290625792245079229',
#   'title': '<b>Flamengo</b> x Bolívar: onde assistir ao vivo, horário e escalações - ge - Globo',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://ge.globo.com/futebol/times/flamengo/noticia/2024/08/15/flamengo-x-bolivar-onde-assistir-ao-vivo-horario-e-escalacoes.ghtml&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw3UnV8OmS2xY19jTTYqihFM',
#   'source': 'geglobo',
#   'tilnow': 3.5601866733333334,
#   'publishedAt': '2024-08-15T15:31:42Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:2048659129158832255',
#   'title': 'Ao vivo: <b>Flamengo</b> x Bolívar | 8ª de final | Taça Conmebol Libertadores - ge',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://ge.globo.com/futebol/libertadores/jogo/15-08-2024/flamengo-bolivar.ghtml&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw0LuBI0N_tbvPTJj9CQbVHV',
#   'source': 'geglobo',
#   'tilnow': 3.6657422288888886,
#   'publishedAt': '2024-08-15T15:25:22Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:620604284697648212',
#   'title': 'Último treino do <b>Flamengo</b> para jogo com Bolívar no Maracanã - GZH',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://gauchazh.clicrbs.com.br/esportes/noticia/2024/08/ultimo-treino-do-flamengo-para-jogo-com-bolivar-no-maracana-clzups810000z01dg4p3z1x8q.html&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw00XCOY3EdcwjBysXGR8sxK',
#   'source': 'outro',
#   'tilnow': 3.7412977844444444,
#   'publishedAt': '2024-08-15T15:20:50Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:2909672748542839405',
#   'title': '<b>Flamengo</b> x Bolívar: transmissão ao vivo e onde assistir o jogo - UOL',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://www.uol.com.br/esporte/futebol/ultimas-noticias/2024/08/15/flamengo-x-bolivar-transmissao-ao-vivo-e-onde-assistir-o-jogo.htm&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw1F0KRRIHxNkH4NMf47R2P0',
#   'source': 'uol',
#   'tilnow': 4.0415755622222225,
#   'publishedAt': '2024-08-15T15:02:49Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:15112827894875842001',
#   'title': '<b>Flamengo</b> x Bolívar: onde assistir e horário pela Copa Libertadores - Exame',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://exame.com/esporte/flamengo-x-bolivar-onde-assistir-e-horario-pela-copa-libertadores/&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw3rQELORnkUIOXuz-MaO7Rv',
#   'source': 'outro',
#   'tilnow': 4.1746311177777775,
#   'publishedAt': '2024-08-15T14:54:50Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:5122420311521060990',
#   'title': 'Presidente do <b>Flamengo</b> projeta data de inauguração do novo estádio; saiba quando será',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://exame.com/esporte/presidente-do-flamengo-projeta-data-de-inauguracao-do-novo-estadio-saiba-quando-sera/&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw0FCAY4Ad71QxL1sMUK6EkG',
#   'source': 'outro',
#   'tilnow': 4.474908895555555,
#   'publishedAt': '2024-08-15T14:36:49Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:15732530583466363158',
#   'title': '<b>Flamengo</b> x Bolívar: onde assistir ao jogo da Libertadores - Giz Brasil - UOL',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://gizmodo.uol.com.br/onde-assistir-flamengo-bolivar-copa-libertadores/&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw3K8lvWRewziQhr16Y0BF5-',
#   'source': 'uol',
#   'tilnow': 4.778242228888889,
#   'publishedAt': '2024-08-15T14:18:37Z'},
#  {'id': 'tag:google.com,2013:googlealerts/feed:14057765574479521460',
#   'title': '<b>Flamengo</b> realiza evento para homenagear medalhistas olímpicos de Paris-2024',
#   'url': 'https://www.google.com/url?rct=j&sa=t&url=https://www.flamengo.com.br/noticias/institucional/flamengo-realiza-evento-para-homenagear-medalhistas-olimpicos-de-paris-2024&ct=ga&cd=CAIyHTJmNTc2YWJhNTI3Y2MzYjY6Y29tLmJyOnB0OkJS&usg=AOvVaw2Cxsx0rm4e17uK44pnosO5',
#   'source': 'flamengo',
#   'tilnow': 5.074631117777778,
#   'publishedAt': '2024-08-15T14:00:50Z'}]
